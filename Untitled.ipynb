# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
clustered = pd.read_csv('new_clustered.csv')
varietal = pd.read_csv('new_varietal.csv')

# %%
print(len(clustered.country.unique()))
len(varietal.country.unique())
# Out:
# 14
# 18

# %%
clustered
# Out:
# array(['Touriga Nacional', 'Tempranillo', 'Sangiovese', 'x', 'Pinot Noir',
#        'Malbec', 'Shiraz/Syrah', 'Cabernet Sauvignon', 'Riesling'],
#       dtype=object)

# %%
clustered.groupby(['country','type']).count()
# Out:
#                          wine_id  wine_name  winery  region  varietal_name  \
# country       type
# Argentina     Red            390        390     390     390            390
#               White           71         71      71      71             71
# Australia     Red            344        344     344     344            344
#               White           64         64      64      64             64
# Brazil        Red              3          3       3       3              3
#               Sparkling        1          1       1       1              1
# Chile         Red            211        211     211     211            211
#               White           50         50      50      50             50
# France        Red           1918       1918    1918    1918           1918
#               Rosé           232        232     232     232            232
#               Sparkling     1026       1026    1026    1026           1026
# ...

# %%
sns.countplot(clustered['type'])
# Out:
# /Users/juliavazquezperez/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='type', ylabel='count'>

# %%
import plotly.express as px 

df=px.data.tips()
fig=px.bar(varietal,x='type',y='country', orientation='h')
st.write(fig)
# Out:
# Figure({
#     'data': [{'alignmentgroup': 'True',
#               'hovertemplate': 'type=%{x}<br>country=%{y}<extra></extra>',
#               'legendgroup': '',
#               'marker': {'color': '#636efa', 'pattern': {'shape': ''}},
#               'name': '',
#               'offsetgroup': '',
#               'orientation': 'h',
#               'showlegend': False,
#               'textposition': 'auto',
#               'type': 'bar',
#               'x': array(['Red', 'Red', 'Red', ..., 'Rosé', 'Rosé', 'Rosé'], dtype=object),
#               'xaxis': 'x',
#               'y': array(['Portugal', 'Portugal', 'Portugal', ..., 'Chile', 'Chile', 'Chile'],
#                          dtype=object),
#               'yaxis': 'y'}],
#     'layout': {'barmode': 'relative',
#                'legend': {'tracegroupgap': 0},
#                'margin': {'t': 60},
#                'template': '...',
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'type'}},
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)


plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
people = ('Tom', 'Dick', 'Harry', 'Slim', 'Jim')
y_pos = np.arange(len(people))
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

ax.barh(y_pos, performance, xerr=error, align='center')
ax.set_yticks(y_pos, labels=people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Performance')
ax.set_title('How fast do you want to go today?')

plt.show()

# %%
varietal.grapes_1_name.unique()
# Out:
# array(['Touriga Nacional', 'Tempranillo', 'Sangiovese', 'x', 'Pinot Noir',
#        'Malbec', 'Shiraz/Syrah', 'Cabernet Sauvignon', 'Riesling'],
#       dtype=object)

# %%
list_1 = list(clustered.grapes_1_name.unique())
list_2 = list(clustered.grapes_2_name.unique())
list_3 = list(clustered.grapes_3_name.unique())

# %%
for i in list_2:
    if i in list_1:
        pass
    else:
        list_1.append(i)
        
len(list_1)
# Out:
# 15

# %%
for i in list_3:
    if i in list_1:
        pass
    else:
        list_1.append(i)
        
len(list_1)
# Out:
# 18

# %%
sorted(list_1)
# Out:
# ['Cabernet Sauvignon',
#  'Carménère',
#  'Chardonnay',
#  'Chasselas',
#  'Garnacha',
#  'Malbec',
#  'Merlot',
#  'Pinot Noir',
#  'Riesling',
#  'Sangiovese',
#  'Sauvignon Blanc',
#  'Shiraz/Syrah',
#  'Spätburgunder',
#  'Tempranillo',
#  'Tinta Roriz',
#  'Touriga Franca',
#  'Touriga Nacional',
#  'Weissburgunder']

# %%
clustered.varietal_name.unique()
# Out:
# array(['Red', 'Cabernet Sauvignon', 'Garnacha', 'Mencía', 'Merlot',
#        'Monastrell', 'Blend del Ródano', 'Rioja', 'Syrah', 'Tempranillo',
#        'Amarone', 'Barbaresco', 'Barolo', 'Bolgheri', 'Brunello',
#        'Chianti', 'Nebbiolo', 'Pinot Noir', 'Ripasso', 'Primitivo',
#        'Barbera', 'Sangiovese', 'Montepulciano', 'Cannonau', 'Albariño',
#        'Bonarda', 'Blend de Burdeos', 'White', 'Cabernet', 'Carménère',
#        'Chablis', 'Chardonnay', 'Chenin blanc', 'Côte-Rotie', 'Gavi',
#        'Gewürztraminer', 'Malbec', 'Müller Thurgau', 'Pinot Blanc',
#        'Pinot Gris', 'Grauburgunder', 'Spätburgunder', 'Pinotage',
#        'Riesling', 'Sauvignon Blanc', 'Jerez', 'Soave', 'Shiraz',
#        'Verdejo', 'Vinho verde', 'Viognier', 'Zinfandel',
#        'Cabernet Franc', 'Silvaner', 'Médoc', 'Margaux', 'Pauillac',
#        'Pomerol', 'Libourne', 'Torrontés', 'Moscatel', 'Saint-Estèphe',
#        'Cote Nuits', 'Cote Beaune', 'Cote Chalonnaise', 'Maconnais',
# ...

# %%
grapes = ['Chardonnay',
 'Chasselas',
 'Garnacha']

# %%
varietal[(varietal['grapes_1_name'].isin(grapes))|(varietal['grapes_2_name'].isin(grapes))|(varietal['grapes_3_name'].isin(grapes))]
# Out:
#          wine_id  type                                          wine_name  \
# 83      87581774   Red                  Abadía Retuerta Pago Valdebellón
# 84     169603165   Red                  Abadía Retuerta Pago Valdebellón
# 85      15749491   Red            Collbaix Celler El Molí Singular Negre
# 86      22822239   Red  Jean Leon Vinya La Scala Gran Reserva Cabernet...
# 87      26199623   Red                  Abadía Retuerta Pago Valdebellón
# ...          ...   ...                                                ...
# 24765  168983725  Rosé                         Amisfield Pinot Noir Rosé
# 24766  172524026  Rosé                         Amisfield Pinot Noir Rosé
# 24767  172587752  Rosé               Terra Sancta Estate Pinot Noir Rosé
# 24768  164309801  Rosé                                The Ned Pinot Rosé
# 24769  168831592  Rosé                                Black Cottage Rosé
#
#            country           region       varietal_name  \
# ...

# %%
varietal['grapes_1_name']
# Out:
# False    24777
# Name: grapes_1_name, dtype: int64

# %%
varietal[(varietal['country']=='Italy')&(varietal['varietal_name']=='Cabernet Sauvignon')]
# Out:
#          wine_id type                             wine_name country  \
# 18758  157494179  Red  Tasca d'Almerita Cabernet Sauvignon    Italy
#
#               region       varietal_name            winery  year  \
# 18758  Vino d'Italia  Cabernet Sauvignon  Tasca d'Almerita  2004
#
#       grapes_1_name grapes_2_name grapes_3_name  \
# 18758             x             x             x
#
#                                 name_folded  \
# 18758  tasca d'almerita cabernet sauvignon
#
#                                               tokenized
# 18758  ['tasca', "d'almerita", 'cabernet', 'sauvignon']

# %%
clustered[clustered['country']=='Brazil']['wine_name'].values
# Out:
# array(['Miolo Lote 43 Cabernet Sauvignon - Merlot ',
#        'Aurora Varietal Merlot ',
#        'Casa Valduga Raízes Premium Cabernet Sauvignon ',
#        'Casa Venturini Vivere Moscatel '], dtype=object)
